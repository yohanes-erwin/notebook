# %% [markdown]
# <a href="https://colab.research.google.com/github/yohanes-erwin/notebook/blob/main/pandas_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Membuat DataFrame dari dictionary of list

# %%
data = {"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],
        "score":[90,80,85,75,95,60,65],
        "sport":["Wrestling","Football","Skiing","Swimming","Tennis","Karete","Surfing"],
        "sex":["M","M","M","M","F","F","F"]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karete   F
# 6     Kate     65    Surfing   F

# %% [markdown]
# Membuat DataFrame baru dengan urutan kolom berbeda

# %%
df = pd.DataFrame(data, columns=["name","sport","sex","score"])
df
# Out:
#       name      sport sex  score
# 0     Bill  Wrestling   M     90
# 1      Tom   Football   M     80
# 2      Tim     Skiing   M     85
# 3     John   Swimming   M     75
# 4     Alex     Tennis   F     95
# 5  Vanessa     Karete   F     60
# 6     Kate    Surfing   F     65

# %% [markdown]
# Mengambil beberapa baris dari atas atau bawah

# %%
df.head()
# Out:
#    name      sport sex  score
# 0  Bill  Wrestling   M     90
# 1   Tom   Football   M     80
# 2   Tim     Skiing   M     85
# 3  John   Swimming   M     75
# 4  Alex     Tennis   F     95

# %%
df.head(2)
# Out:
#    name      sport sex  score
# 0  Bill  Wrestling   M     90
# 1   Tom   Football   M     80

# %%
df.tail()
# Out:
#       name     sport sex  score
# 2      Tim    Skiing   M     85
# 3     John  Swimming   M     75
# 4     Alex    Tennis   F     95
# 5  Vanessa    Karete   F     60
# 6     Kate   Surfing   F     65

# %%
df.tail(3)
# Out:
#       name    sport sex  score
# 4     Alex   Tennis   F     95
# 5  Vanessa   Karete   F     60
# 6     Kate  Surfing   F     65

# %% [markdown]
# Membuat DataFrame baru dengan kolom dari DataFrame sebelumnya dan juga kolom baru

# %%
df = pd.DataFrame(data, columns=["name", "sport", "gender", "score", "age"])
df
# Out:
#       name      sport gender  score  age
# 0     Bill  Wrestling    NaN     90  NaN
# 1      Tom   Football    NaN     80  NaN
# 2      Tim     Skiing    NaN     85  NaN
# 3     John   Swimming    NaN     75  NaN
# 4     Alex     Tennis    NaN     95  NaN
# 5  Vanessa     Karete    NaN     60  NaN
# 6     Kate    Surfing    NaN     65  NaN

# %% [markdown]
# Mengganti penamaan index (baris)

# %%
df = pd.DataFrame(data, columns=["name", "sport", "gender", "score", "age"],
                  index=["one","two","three","four","five","six","seven"])
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90  NaN
# two        Tom   Football    NaN     80  NaN
# three      Tim     Skiing    NaN     85  NaN
# four      John   Swimming    NaN     75  NaN
# five      Alex     Tennis    NaN     95  NaN
# six    Vanessa     Karete    NaN     60  NaN
# seven     Kate    Surfing    NaN     65  NaN

# %% [markdown]
# Mengambil satu kolom dari DataFrame menjadi Series

# %%
df["sport"]
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %%
type(df["sport"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Mengambil lebih dari satu kolom menjadi DataFrame yang lebih kecil

# %%
my_columns = ["name","sport"]
df[my_columns]
# Out:
#           name      sport
# one       Bill  Wrestling
# two        Tom   Football
# three      Tim     Skiing
# four      John   Swimming
# five      Alex     Tennis
# six    Vanessa     Karete
# seven     Kate    Surfing

# %%
type(df[my_columns])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Cara lain untuk mengambil satu kolom dari DataFrame

# %%
df.sport
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %% [markdown]
# Mengambil satu baris dari DataFrame

# %%
df.loc[["one"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling    NaN     90  NaN

# %% [markdown]
# Mengambil lebih dari satu baris dari DataFrame

# %%
df.loc[["one","two"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling    NaN     90  NaN
# two   Tom   Football    NaN     80  NaN

# %% [markdown]
# Mengisi sebuah kolom dengan data yang sama untuk semua baris

# %%
df["age"] = 18

# %%
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90   18
# two        Tom   Football    NaN     80   18
# three      Tim     Skiing    NaN     85   18
# four      John   Swimming    NaN     75   18
# five      Alex     Tennis    NaN     95   18
# six    Vanessa     Karete    NaN     60   18
# seven     Kate    Surfing    NaN     65   18

# %% [markdown]
# Mengisi kolom dengan list

# %%
df = pd.DataFrame(data, columns=["name", "sport", "gender", "score", "age"],
                  index=["one","two","three","four","five","six","seven"])
values = [18,19,20,18,17,17,18]
df["age"] = values
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90   18
# two        Tom   Football    NaN     80   19
# three      Tim     Skiing    NaN     85   20
# four      John   Swimming    NaN     75   18
# five      Alex     Tennis    NaN     95   17
# six    Vanessa     Karete    NaN     60   17
# seven     Kate    Surfing    NaN     65   18

# %% [markdown]
# Menambah kolom baru berdasarkan kondisi dari kolom sebelumnya

# %%
df["pass"] = df.score>=70
df
# Out:
#           name      sport gender  score  age   pass
# one       Bill  Wrestling    NaN     90   18   True
# two        Tom   Football    NaN     80   19   True
# three      Tim     Skiing    NaN     85   20   True
# four      John   Swimming    NaN     75   18   True
# five      Alex     Tennis    NaN     95   17   True
# six    Vanessa     Karete    NaN     60   17  False
# seven     Kate    Surfing    NaN     65   18  False

# %% [markdown]
# Menghapus kolom dari DataFrame

# %%
del df["pass"]
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90   18
# two        Tom   Football    NaN     80   19
# three      Tim     Skiing    NaN     85   20
# four      John   Swimming    NaN     75   18
# five      Alex     Tennis    NaN     95   17
# six    Vanessa     Karete    NaN     60   17
# seven     Kate    Surfing    NaN     65   18
